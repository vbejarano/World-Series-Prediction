# %%
import pandas as pd
from textblob import TextBlob
import tweepy
import pandas as pd
import numpy as np
import json
import sys
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.tokenize import TweetTokenizer 
import nltk
from textblob.classifiers import NaiveBayesClassifier

# %%
g3full = pd.read_csv('g3full.csv')
g4full = pd.read_csv('g4full.csv')
g5full = pd.read_csv('g5full.csv')
g3full.drop(columns=['Unnamed: 0','Unnamed: 0.1', 'Unnamed: 0.1.1'])
g4full.drop(columns=['Unnamed: 0','Unnamed: 0.1', 'Unnamed: 0.1.1'])
g5full.drop(columns=['Unnamed: 0','Unnamed: 0.1', 'Unnamed: 0.1.1'])
# Out:
#                             Location  \
# 0                                USA
# 1                      San Francisco
# 2                      chickasha, OK
# 3                        Attalla, AL
# 4                            Houston
# 5                                NaN
# 6                                TX
# 7                        Houston, TX
# 8                                NaN
# 9                         Texas, USA
# 10                   Houston, Texas.
# 11                               NaN
# 12             Lake of the Woods, CA
# 13             College Station/Bryan
# 14                         Omaha, NE
# 15                           Alief 🍎
# 16                Corpus Christi, TX
# 17                    Houston, Texas
# 18                   Clutch City, Tx
# 19                Port Hope, Ontario
# 20                       Houston, TX
# 21                   California, USA
# 22                        In my bag💸
# 23                     Houston,Texas
# ...

# %%
#calculating/cleaning compound
compoundscores = [astros['Score'] for x in astros]
