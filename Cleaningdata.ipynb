# %%
import pandas as pd

# %%
a1 = pd.read_csv('Astrosg4_1.csv')
a3 = pd.read_csv('Astrosg4_3.csv')
a4 = pd.read_csv('Astrosg4_4.csv')
a5 = pd.read_csv('Astrosg4_5.csv')
a7 = pd.read_csv('Astrosg4_7.csv')
a8 = pd.read_csv('Astrosg4_8.csv')
a9 = pd.read_csv('Astrosg4_9.csv')
a10 = pd.read_csv('Astrosg4_10.csv')
a11 = pd.read_csv('Astrosg4_11.csv')
a12 = pd.read_csv('Astrosg4_12.csv')
a13 = pd.read_csv('Astrosg4_13.csv')

# %%
n1 = pd.read_csv('Natg4_1.csv')
n3 = pd.read_csv('Natg4_3.csv')
n4 = pd.read_csv('Natg4_4.csv')
n5 = pd.read_csv('Natg4_5.csv')
n7 = pd.read_csv('Natg4_7.csv')
n8 = pd.read_csv('Natg4_8.csv')
n9 = pd.read_csv('Natg4_9.csv')
n10 = pd.read_csv('Natg4_10.csv')
n11 = pd.read_csv('Natg4_11.csv')
n12 = pd.read_csv('Natg4_12.csv')
n13 = pd.read_csv('Natg4_13.csv')

# %%
w1 = pd.read_csv('Wsg4_1.csv')
w3 = pd.read_csv('Wsg4_3.csv')
w4 = pd.read_csv('Wsg4_4.csv')
w5 = pd.read_csv('Wsg4_5.csv')
w7 = pd.read_csv('Wsg4_7.csv')
w8 = pd.read_csv('Wsg4_8.csv')
w9 = pd.read_csv('Wsg4_9.csv')
w10 = pd.read_csv('Wsg4_10.csv')
w11 = pd.read_csv('Wsg4_11.csv')
w12 = pd.read_csv('Wsg4_12.csv')
w13 = pd.read_csv('Wsg4_13.csv')

# %%
astros = pd.concat([a1, a3, a4, a5, a7, a8, a9, a10, a11, a12, a13])

# %%
ws = pd.concat([w1, w3, w4, w5, w7, w8, w9, w10, w11, w12, w13])

# %%
nats = pd.concat([n1, n3, n4, n5, n7, n8, n9, n10, n11, n12, n13])

# %%
astros.to_csv('Game5Astros.csv')
ws.to_csv('Game5ws.csv')
nats.to_csv('Game5nats.csv')

# %%
astros.head(1)
# Out:
#    Unnamed: 0   Location                                              Score  \
# 0           0  Ohio, USA  {'neg': 0.0, 'neu': 0.81, 'pos': 0.19, 'compou...
#
#                   Time                                              Tweet  \
# 0  2019-10-27 00:10:21  RT  : ⚾️GIVEAWAY⚾️ What's your favorite part a...
#
#       User Name
# 0  🌸CarlaMarie🌸

# %%
type(astros.Score)
# Out:
# pandas.core.series.Series

# %%
compoundastros = []
print(astros)
# Out:
#     Unnamed: 0                                              Score  \
# 0            0  {'neg': 0.423, 'neu': 0.577, 'pos': 0.0, 'comp...
# 1            1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2            2  {'neg': 0.083, 'neu': 0.62, 'pos': 0.297, 'com...
# 3            3  {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compou...
# 4            4  {'neg': 0.0, 'neu': 0.717, 'pos': 0.283, 'comp...
# 5            5  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6            6  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7            7  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 8            8  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9            9  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10          10  {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'comp...
# 11          11  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 12          12  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...

# %%
g3a = pd.read_csv('Game3Astros.csv')
g3n = pd.read_csv('Game3nats.csv')
g3w = pd.read_csv('Game3ws.csv')
g4a = pd.read_csv('Game4Astros.csv')
g4n = pd.read_csv('Game4nats.csv')
g4w = pd.read_csv('Game4ws.csv')
g5a = pd.read_csv('Game5Astros.csv')
g5n = pd.read_csv('Game5nats.csv')
g5w = pd.read_csv('Game5ws.csv')

# %%
astrosfull = pd.concat([g3a, g4a, g5a])
natsfull = pd.concat([g3n, g4n, g5n])
wsfull = pd.concat([g3w, g4w, g5w])

g3full = pd.concat([g3a, g3n, g3w])
g4full = pd.concat([g4a, g4n, g4w])
g5full = pd.concat([g5a, g5n, g5w])
# Out:
# C:\Users\My Nigga\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# C:\Users\My Nigga\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# C:\Users\My Nigga\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
# ...

# %%
astrosfull.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
natsfull.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
wsfull.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
# Out:
#                             Location  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13                               NaN
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                               NaN
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# ...

# %%
g3full.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
g4full.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
g5full.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
g3full.to_csv('g3full.csv')
g4full.to_csv('g4full.csv')
g5full.to_csv('g5full.csv')

# %%
#calculating/cleaning compound
compoundscores = [astros['Score'] for x in astros]
